# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Names":["lavanya",None,"jaanu",np.nan,"lakshit","dakshith"],
    "ages":[20,np.nan,21,19,10,8],
    "marks":[98,None,95,np.nan,85,75]
}
df = pd.DataFrame(data)
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.isnull()
# Out:
#    Names   ages  marks
# 0  False  False  False
# 1   True   True   True
# 2  False  False  False
# 3   True  False   True
# 4  False  False  False
# 5  False  False  False

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.isnull().sum()
# Out:
# Names    2
# ages     1
# marks    2
# dtype: int64

# %%
df['Names'].replace(np.nan,'jack')
# Out:
# 0     lavanya
# 1        jack
# 2       jaanu
# 3        jack
# 4     lakshit
# 5    dakshith
# Name: Names, dtype: object

# %%
df.dtypes
# Out:
# Names     object
# ages     float64
# marks    float64
# dtype: object

# %%
avg_ages = df['ages'].median()
avg_ages
# Out:
# 19.0

# %%
df['ages']
# Out:
# 0    20.0
# 1     NaN
# 2    21.0
# 3    19.0
# 4    10.0
# 5     8.0
# Name: ages, dtype: float64

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df['ages'].replace(np.nan,avg_ages)
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
avg_mark = df['marks'].median()
avg_mark
# Out:
# 90.0

# %%
df["marks"]
# Out:
# 0    98.0
# 1     NaN
# 2    95.0
# 3     NaN
# 4    85.0
# 5    75.0
# Name: marks, dtype: float64

# %%
df["marks"].replace(np.nan, avg_mark)
# Out:
# 0    98.0
# 1    90.0
# 2    95.0
# 3    90.0
# 4    85.0
# 5    75.0
# Name: marks, dtype: float64

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna()
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 2     jaanu  21.0   95.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df['Names'].value_counts()
# Out:
# Names
# jack        2
# lavanya     1
# jaanu       1
# lakshit     1
# dakshith    1
# Name: count, dtype: int64

# %%
df.replace(np.nan,'jack')
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      jack  19.0   90.0
# 2     jaanu  21.0   95.0
# 3      jack  19.0   90.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis=0)
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 2     jaanu  21.0   95.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis='index')
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 2     jaanu  21.0   95.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis='columns')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis='index', how="any")
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 2     jaanu  21.0   95.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.dropna(axis="index",how="all")
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df.fillna('jack')
# Out:
#       Names  ages marks
# 0   lavanya  20.0  98.0
# 1      jack  jack  jack
# 2     jaanu  21.0  95.0
# 3      jack  19.0  jack
# 4   lakshit  10.0  85.0
# 5  dakshith   8.0  75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      None   NaN    NaN
# 2     jaanu  21.0   95.0
# 3       NaN  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df['Names'].fillna('jack',inplace=True)
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_11168\2988823906.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Names'].fillna('jack',inplace=True)

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      jack   NaN    NaN
# 2     jaanu  21.0   95.0
# 3      jack  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df['ages'].fillna(avg_ages,inplace=True)

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      jack  19.0    NaN
# 2     jaanu  21.0   95.0
# 3      jack  19.0    NaN
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df['marks'].fillna(avg_mark,inplace=True)
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      jack  19.0   90.0
# 2     jaanu  21.0   95.0
# 3      jack  19.0   90.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

# %%
df
# Out:
#       Names  ages  marks
# 0   lavanya  20.0   98.0
# 1      jack  19.0   90.0
# 2     jaanu  21.0   95.0
# 3      jack  19.0   90.0
# 4   lakshit  10.0   85.0
# 5  dakshith   8.0   75.0

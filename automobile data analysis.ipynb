# %%
#import pandas
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Sanjay\\OneDrive\\Desktop\\pandas\\auto.csv")
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
#put custom headings inside the list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
#replace the column names with the names inside the list
df.columns = headers

# %%
#check whether the heading is setted
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (204, 26)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
#tail()
df.tail(50)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 154          0                91      toyota       gas        std
# 155          0                91      toyota       gas        std
# 156          0                91      toyota       gas        std
# 157          0                91      toyota    diesel        std
# 158          0                91      toyota    diesel        std
# 159          0                91      toyota       gas        std
# 160          0                91      toyota       gas        std
# 161          0                91      toyota       gas        std
# 162          1               168      toyota       gas        std
# 163          1               168      toyota       gas        std
# 164          1               168      toyota       gas        std
# 165          1               168      toyota       gas        std
# 166          2               134      toyota       gas        std
# ...

# %%
#info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
#describe()
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
#describe(include="all")
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   204.000000               204     204       204        204
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                40      32       184        167
# mean      0.823529               NaN     NaN       NaN        NaN
# std       1.239035               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           204        204          204             204  204.000000  ...
# ...

# %%
#find the null values
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            1                 ?    alfa-romero       gas        std
# 2            2               164           audi       gas        std
# 3            2               164           audi       gas        std
# 4            2                 ?           audi       gas        std
# 5            1               158           audi       gas        std
# 6            1                 ?           audi       gas        std
# 7            1               158           audi       gas      turbo
# 8            0                 ?           audi       gas      turbo
# 9            2               192            bmw       gas        std
# 10           0               192            bmw       gas        std
# 11           0               188            bmw       gas        std
# 12           0               188            bmw       gas        std
# ...

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',100)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df['price'].unique()
# Out:
# array(['16500', '13950', '17450', '15250', '17710', '18920', '23875', '?',
#        '16430', '16925', '20970', '21105', '24565', '30760', '41315',
#        '36880', '5151', '6295', '6575', '5572', '6377', '7957', '6229',
#        '6692', '7609', '8558', '8921', '12964', '6479', '6855', '5399',
#        '6529', '7129', '7295', '7895', '9095', '8845', '10295', '12945',
#        '10345', '6785', '11048', '32250', '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['bore'].unique()
# Out:
# array(['3.47', '2.68', '3.19', '3.13', '3.50', '3.31', '3.62', '2.91',
#        '3.03', '2.97', '3.34', '3.60', '2.92', '3.15', '3.43', '3.63',
#        '3.54', '3.08', '?', '3.39', '3.76', '3.58', '3.46', '3.80',
#        '3.78', '3.17', '3.35', '3.59', '2.99', '3.33', '3.70', '3.61',
#        '3.94', '3.74', '2.54', '3.05', '3.27', '3.24', '3.01'],
#       dtype=object)

# %%
df['stroke'].unique()
# Out:
# array(['2.68', '3.47', '3.40', '2.80', '3.19', '3.39', '3.03', '3.11',
#        '3.23', '3.46', '3.90', '3.41', '3.07', '3.58', '4.17', '2.76',
#        '3.15', '?', '3.16', '3.64', '3.10', '3.35', '3.12', '3.86',
#        '3.29', '3.27', '3.52', '2.19', '3.21', '2.90', '2.07', '2.36',
#        '2.64', '3.08', '3.50', '3.54', '2.87'], dtype=object)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
for i in headers:
    print("Column name=",i)
    print(df[i].unique())
    print('-------------------------------------------------------------------------------------------------')
# Out:
# Column name= symboling
# [ 3  1  2  0 -1 -2]
# -------------------------------------------------------------------------------------------------
# Column name= normalized-losses
# ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# -------------------------------------------------------------------------------------------------
# Column name= make
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# -------------------------------------------------------------------------------------------------
# Column name= fuel-type
# ['gas' 'diesel']
# ...

# %%
import numpy as np
df['normalized-losses'].replace('?',np.nan,inplace=True)
df['normalized-losses'].unique()
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\3159715464.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].replace('?',np.nan,inplace=True)
# array([nan, '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
# ...

# %%
df['bore'].replace("?",np.nan,inplace=True)
df['bore'].unique()
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\806628126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bore'].replace("?",np.nan,inplace=True)
# array(['3.47', '2.68', '3.19', '3.13', '3.50', '3.31', '3.62', '2.91',
#        '3.03', '2.97', '3.34', '3.60', '2.92', '3.15', '3.43', '3.63',
#        '3.54', '3.08', nan, '3.39', '3.76', '3.58', '3.46', '3.80',
#        '3.78', '3.17', '3.35', '3.59', '2.99', '3.33', '3.70', '3.61',
#        '3.94', '3.74', '2.54', '3.05', '3.27', '3.24', '3.01'],
# ...

# %%
df['stroke'].replace("?",np.nan,inplace=True)
df['stroke'].unique()
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\2447752886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['stroke'].replace("?",np.nan,inplace=True)
# array(['2.68', '3.47', '3.40', '2.80', '3.19', '3.39', '3.03', '3.11',
#        '3.23', '3.46', '3.90', '3.41', '3.07', '3.58', '4.17', '2.76',
#        '3.15', nan, '3.16', '3.64', '3.10', '3.35', '3.12', '3.86',
#        '3.29', '3.27', '3.52', '2.19', '3.21', '2.90', '2.07', '2.36',
#        '2.64', '3.08', '3.50', '3.54', '2.87'], dtype=object)

# %%
df['price'].replace("?",np.nan,inplace=True) 
df['price'].unique()
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\3969944376.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].replace("?",np.nan,inplace=True)
# array(['16500', '13950', '17450', '15250', '17710', '18920', '23875', nan,
#        '16430', '16925', '20970', '21105', '24565', '30760', '41315',
#        '36880', '5151', '6295', '6575', '5572', '6377', '7957', '6229',
#        '6692', '7609', '8558', '8921', '12964', '6479', '6855', '5399',
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df['normalized-losses'].dtypes
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
df['normalized-losses'] = pd.to_numeric(df['normalized-losses'])
df['normalized-losses']
# Out:
# 0        NaN
# 1        NaN
# 2      164.0
# 3      164.0
# 4        NaN
#        ...
# 199     95.0
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# Name: normalized-losses, Length: 204, dtype: float64

# %%
avg_normalized_loss = df['normalized-losses'].mean()
avg_normalized_loss
# Out:
# 122.0

# %%
df['normalized-losses'].fillna(avg_normalized_loss, inplace=True)
df['normalized-losses'].unique()
# Out:
# array([122., 164., 158., 192., 188., 121.,  98.,  81., 118., 148., 110.,
#        145., 137., 101.,  78., 106.,  85., 107., 104., 113., 150., 129.,
#        115.,  93., 142., 161., 153., 125., 128., 103., 168., 108., 194.,
#        231., 119., 154.,  74., 186.,  83., 102.,  89.,  87.,  77.,  91.,
#        134.,  65., 197.,  90.,  94., 256.,  95.])

# %%
"""changing datatypes of multiple columns"""
df[["bore","stroke","price"]]=df[["bore","stroke","price"]].astype({"bore":"float", "stroke":"float", "price":"float"})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    float64
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
avg_price = df['price'].mean()
avg_price
# Out:
# 13205.69

# %%
df['price'].fillna(avg_price, inplace=True)
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\1751826378.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(avg_price, inplace=True)

# %%
avg_bore = df['bore'].mean()
avg_bore
# Out:
# 3.3290499999999996

# %%
df['bore'].fillna(avg_bore, inplace =True)
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\394659061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bore'].fillna(avg_bore, inplace =True)

# %%
avg_stroke = df['stroke'].mean()
avg_stroke
# Out:
# 3.2582999999999993

# %%
df['stroke'].fillna(avg_stroke,inplace=True)
# Out:
# C:\Users\Sanjay\AppData\Local\Temp\ipykernel_7996\3647844236.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['stroke'].fillna(avg_stroke,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          1              122.0  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              122.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two    hatchback          rwd           front        94.5   171.2
# 2         four        sedan          fwd           front        99.8   176.6
# 3         four        sedan          4wd           front        99.4   176.6
# 4          two        sedan          fwd           front        99.8   177.3
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
filt=df['make'] == 'honda'
df.loc[filt,["make","fuel-type","price"]]
# Out:
#      make fuel-type    price
# 29  honda       gas   6479.0
# 30  honda       gas   6855.0
# 31  honda       gas   5399.0
# 32  honda       gas   6529.0
# 33  honda       gas   7129.0
# 34  honda       gas   7295.0
# 35  honda       gas   7295.0
# 36  honda       gas   7895.0
# 37  honda       gas   9095.0
# 38  honda       gas   8845.0
# 39  honda       gas  10295.0
# 40  honda       gas  12945.0
# 41  honda       gas  10345.0

# %%
filt=df['make'] == 'toyota'
df.loc[filt,["make","fuel-type","price"]]
# Out:
#        make fuel-type    price
# 149  toyota       gas   5348.0
# 150  toyota       gas   6338.0
# 151  toyota       gas   6488.0
# 152  toyota       gas   6918.0
# 153  toyota       gas   7898.0
# 154  toyota       gas   8778.0
# 155  toyota       gas   6938.0
# 156  toyota       gas   7198.0
# 157  toyota    diesel   7898.0
# 158  toyota    diesel   7788.0
# 159  toyota       gas   7738.0
# 160  toyota       gas   8358.0
# 161  toyota       gas   9258.0
# 162  toyota       gas   8058.0
# 163  toyota       gas   8238.0
# 164  toyota       gas   9298.0
# 165  toyota       gas   9538.0
# 166  toyota       gas   8449.0
# 167  toyota       gas   9639.0
# 168  toyota       gas   9989.0
# 169  toyota       gas  11199.0
# 170  toyota       gas  11549.0
# 171  toyota       gas  17669.0
# 172  toyota       gas   8948.0
# 173  toyota    diesel  10698.0
# 174  toyota       gas   9988.0
# 175  toyota       gas  10898.0
# 176  toyota       gas  11248.0
# 177  toyota       gas  16558.0
# ...

# %%
fuel_types = df['fuel-type'].unique().tolist()
fuel_types
# Out:
# ['gas', 'diesel']

# %%
filt=(df['make'] == 'toyota') & (df['fuel-type'] == 'gas')
df.loc[filt].head()
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 149          1               87.0  toyota       gas        std          two
# 150          1               87.0  toyota       gas        std          two
# 151          1               74.0  toyota       gas        std         four
# 152          0               77.0  toyota       gas        std         four
# 153          0               81.0  toyota       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 149  hatchback          fwd           front        95.7   158.7   63.6
# 150  hatchback          fwd           front        95.7   158.7   63.6
# 151  hatchback          fwd           front        95.7   158.7   63.6
# 152      wagon          fwd           front        95.7   169.7   63.6
# 153      wagon          4wd           front        95.7   169.7   63.6
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
for i in fuel_types:
    print("fuel type =",i)
    filt=(df['make'] == 'toyota') & (df['fuel-type'] == i)
    print(df.loc[filt,["make","fuel-type","price"]].head())
    print('------------------------------------------------------------')
# Out:
# fuel type = gas
#        make fuel-type   price
# 149  toyota       gas  5348.0
# 150  toyota       gas  6338.0
# 151  toyota       gas  6488.0
# 152  toyota       gas  6918.0
# 153  toyota       gas  7898.0
# ------------------------------------------------------------
# fuel type = diesel
#        make fuel-type    price
# 157  toyota    diesel   7898.0
# 158  toyota    diesel   7788.0
# 173  toyota    diesel  10698.0
# ------------------------------------------------------------

# %%
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
make_grp = df.groupby(by='make')
make_grp

# %%
make_grp.get_group('audi')["price"].count()
# Out:
# 7

# %%
make_grp.get_group('audi')['price'].sum()
# Out:
# 120360.69

# %%
makes_list = df['make'].unique().tolist()
print(makes_list)
# Out:
# ['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda', 'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury', 'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault', 'saab', 'subaru', 'toyota', 'volkswagen', 'volvo']

# %%
Car_price=[]
for make in makes_list:
    print("car model name=",make)
    price=make_grp.get_group(make)['price'].sum()
    print("car count=",make_grp.get_group(make)['price'].count())
    print("Total price =",price)
    Car_price.append((make,price))
    print('-----------------------------------------------------------------------------------')
# Out:
# car model name= alfa-romero
# car count= 2
# Total price = 33000.0
# -----------------------------------------------------------------------------------
# car model name= audi
# car count= 7
# Total price = 120360.69
# -----------------------------------------------------------------------------------
# car model name= bmw
# car count= 8
# Total price = 208950.0
# -----------------------------------------------------------------------------------
# car model name= chevrolet
# car count= 3
# Total price = 18021.0
# -----------------------------------------------------------------------------------
# car model name= dodge
# car count= 9
# Total price = 70879.0
# -----------------------------------------------------------------------------------
# car model name= honda
# car count= 13
# Total price = 106401.0
# -----------------------------------------------------------------------------------
# car model name= isuzu
# car count= 4
# Total price = 44244.380000000005
# ...

# %%
for i in Car_price:
    print(i,end="")
    print()
# Out:
# ('alfa-romero', 33000.0)
# ('audi', 120360.69)
# ('bmw', 208950.0)
# ('chevrolet', 18021.0)
# ('dodge', 70879.0)
# ('honda', 106401.0)
# ('isuzu', 44244.380000000005)
# ('jaguar', 103800.0)
# ('mazda', 181099.0)
# ('mercedes-benz', 269176.0)
# ('mercury', 16503.0)
# ('mitsubishi', 120117.0)
# ('nissan', 187482.0)
# ('peugot', 170380.0)
# ('plymouth', 55744.0)
# ('porsche', 138807.69)
# ('renault', 19190.0)
# ('saab', 91340.0)
# ('subaru', 102495.0)
# ('toyota', 316346.0)
# ('volkswagen', 120930.0)
# ('volvo', 198695.0)

# %%
make_grp.get_group('bmw')['price'].count()
# Out:
# 8

# %%
car_count = []
for i in makes_list:
    car_counts = make_grp.get_group(i)['price'].count()
    print(i)
    car_count.append(car_counts)
    print(car_counts)
    print('********************************************************************************')
# Out:
# alfa-romero
# 2
# ********************************************************************************
# audi
# 7
# ********************************************************************************
# bmw
# 8
# ********************************************************************************
# chevrolet
# 3
# ********************************************************************************
# dodge
# 9
# ********************************************************************************
# honda
# 13
# ********************************************************************************
# isuzu
# 4
# ********************************************************************************
# jaguar
# 3
# ********************************************************************************
# mazda
# 17
# ********************************************************************************
# mercedes-benz
# 8
# ********************************************************************************
# mercury
# 1
# ...

# %%
car_count
sort_list=sorted(car_count)
print(sort_list[-1])
# Out:
# 32

# %%
for i in makes_list:
    print(i)
    print(make_grp.get_group(i)['price'].mean())
    print('********************************************************************************')
# Out:
# alfa-romero
# 16500.0
# ********************************************************************************
# audi
# 17194.384285714284
# ********************************************************************************
# bmw
# 26118.75
# ********************************************************************************
# chevrolet
# 6007.0
# ********************************************************************************
# dodge
# 7875.444444444444
# ********************************************************************************
# honda
# 8184.692307692308
# ********************************************************************************
# isuzu
# 11061.095000000001
# ********************************************************************************
# jaguar
# 34600.0
# ********************************************************************************
# mazda
# 10652.882352941177
# ********************************************************************************
# mercedes-benz
# 33647.0
# ...

# %%
car_price = []
for i in makes_list:
    print(i)
    max_price = make_grp.get_group(i)['price'].max()
    print(max_price)
    car_price.append((i,max_price))
    print('********************************************************************************')
# Out:
# alfa-romero
# 16500.0
# ********************************************************************************
# audi
# 23875.0
# ********************************************************************************
# bmw
# 41315.0
# ********************************************************************************
# chevrolet
# 6575.0
# ********************************************************************************
# dodge
# 12964.0
# ********************************************************************************
# honda
# 12945.0
# ********************************************************************************
# isuzu
# 13205.69
# ********************************************************************************
# jaguar
# 36000.0
# ********************************************************************************
# mazda
# 18344.0
# ********************************************************************************
# mercedes-benz
# 45400.0
# ...

# %%
car_price
# Out:
# [('alfa-romero', 16500.0),
#  ('audi', 23875.0),
#  ('bmw', 41315.0),
#  ('chevrolet', 6575.0),
#  ('dodge', 12964.0),
#  ('honda', 12945.0),
#  ('isuzu', 13205.69),
#  ('jaguar', 36000.0),
#  ('mazda', 18344.0),
#  ('mercedes-benz', 45400.0),
#  ('mercury', 16503.0),
#  ('mitsubishi', 14869.0),
#  ('nissan', 19699.0),
#  ('peugot', 18150.0),
#  ('plymouth', 12764.0),
#  ('porsche', 37028.0),
#  ('renault', 9895.0),
#  ('saab', 18620.0),
#  ('subaru', 11694.0),
#  ('toyota', 17669.0),
#  ('volkswagen', 13845.0),
#  ('volvo', 22625.0)]

# %%
for i in makes_list:
    print(i)
    print(make_grp.get_group(i)['price'].min())
    print('********************************************************************************')
# Out:
# alfa-romero
# 16500.0
# ********************************************************************************
# audi
# 13205.69
# ********************************************************************************
# bmw
# 16430.0
# ********************************************************************************
# chevrolet
# 5151.0
# ********************************************************************************
# dodge
# 5572.0
# ********************************************************************************
# honda
# 5399.0
# ********************************************************************************
# isuzu
# 6785.0
# ********************************************************************************
# jaguar
# 32250.0
# ********************************************************************************
# mazda
# 5195.0
# ********************************************************************************
# mercedes-benz
# 25552.0
# ...

# %%
make_fuel_grp = df.groupby(by=["make","fuel-type"])
make_fuel_grp

# %%
Car_Type = []
for name,grp in make_fuel_grp:
    Car_Type.append(name)
    print(name)
# Out:
# ('alfa-romero', 'gas')
# ('audi', 'gas')
# ('bmw', 'gas')
# ('chevrolet', 'gas')
# ('dodge', 'gas')
# ('honda', 'gas')
# ('isuzu', 'gas')
# ('jaguar', 'gas')
# ('mazda', 'diesel')
# ('mazda', 'gas')
# ('mercedes-benz', 'diesel')
# ('mercedes-benz', 'gas')
# ('mercury', 'gas')
# ('mitsubishi', 'gas')
# ('nissan', 'diesel')
# ('nissan', 'gas')
# ('peugot', 'diesel')
# ('peugot', 'gas')
# ('plymouth', 'gas')
# ('porsche', 'gas')
# ('renault', 'gas')
# ('saab', 'gas')
# ('subaru', 'gas')
# ('toyota', 'diesel')
# ('toyota', 'gas')
# ('volkswagen', 'diesel')
# ('volkswagen', 'gas')
# ('volvo', 'diesel')
# ('volvo', 'gas')

# %%
make_fuel_grp.get_group(('mercedes-benz', 'diesel'))["price"]
# Out:
# 66    25552.0
# 67    28248.0
# 68    28176.0
# 69    31600.0
# Name: price, dtype: float64

# %%
make_fuel_grp.get_group(('mercedes-benz', 'diesel'))["price"].sum()
# Out:
# 113576.0

# %%
for i in Car_Type:
    print("Group =",i)
    print("Car Count =",make_fuel_grp.get_group(i)["price"].count())
    print("Total Price =",make_fuel_grp.get_group(i)["price"].sum())
    print("Maximum Price",make_fuel_grp.get_group(i)["price"].max())
    print("Minimum Price =",make_fuel_grp.get_group(i)["price"].min())
    print("Average Price =",make_fuel_grp.get_group(i)["price"].mean())
    print("******************************************")
# Out:
# Group = ('alfa-romero', 'gas')
# Car Count = 2
# Total Price = 33000.0
# Maximum Price 16500.0
# Minimum Price = 16500.0
# Average Price = 16500.0
# ******************************************
# Group = ('audi', 'gas')
# Car Count = 7
# Total Price = 120360.69
# Maximum Price 23875.0
# Minimum Price = 13205.69
# Average Price = 17194.384285714284
# ******************************************
# Group = ('bmw', 'gas')
# Car Count = 8
# Total Price = 208950.0
# Maximum Price 41315.0
# Minimum Price = 16430.0
# Average Price = 26118.75
# ******************************************
# Group = ('chevrolet', 'gas')
# Car Count = 3
# Total Price = 18021.0
# Maximum Price 6575.0
# Minimum Price = 5151.0
# Average Price = 6007.0
# ******************************************
# Group = ('dodge', 'gas')
# Car Count = 9
# Total Price = 70879.0
# Maximum Price 12964.0
# Minimum Price = 5572.0
# Average Price = 7875.444444444444
# ******************************************
# Group = ('honda', 'gas')
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['make'],df['price'])
plt.show()

# %%
df['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2             audi
# 3             audi
# 4             audi
#           ...
# 199          volvo
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# Name: make, Length: 204, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot for the 'price' column
plt.figure(figsize=(8,6))  # Set the figure size
sns.boxplot(x=df['price'])

# Add a title and labels
plt.title('Box Plot of Car Prices')
plt.xlabel('Price')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a box plot for the 'price' column  
plt.boxplot(df['price'])

# Add a title and labels
plt.title('Box Plot of Car Prices')
plt.ylabel('Price')

# Show the plot
plt.show()

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(df['price'])
plt.show()

# %%
df['price'].median()
# Out:
# 10470.0

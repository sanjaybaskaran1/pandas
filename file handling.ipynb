# %%
path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\measures-for-insample-evaluation.txt"

data = open(path, "r", encoding="utf-8")
content = data.read()
data.close()

print(content)
# Out:
# In this lecture we will cover 1d tensors, and teach you about some of the common operations that you will use with tensors when building a neural network, pre-processing your data or analyzing your results.
#
#
#
# Let’s get started! Tensors are arrays that are the building blocks of a neural network. In this lecture, we will learn the basics of 1-D tensors
#
# such as Types, Indexing and Slicing, Basic Operations, Universal Functions
#
#
#
#
# Let’s start by understanding what a 1 D tensor is
#
# A 0-d tensor is just a number,
#
# 1-D tensor is an array of numbers.
#
# It could be: A row in a data database, A vector, Time series
#
#
#
#
# A tensor contains elements of a single data type.
#
# The tensor type is the type of tensor.
#
# When we are dealing with real numbers, the tensor type could either be a float tensor or a double tensor.
#
# When we are dealing with unsigned integers that are used in 8 bit images, the tensor type is a byte tensor.
#
# ...

# %%
with open(path,"r",encoding="utf-8") as data:
    print(data.read())
# Out:
# In this lecture we will cover 1d tensors, and teach you about some of the common operations that you will use with tensors when building a neural network, pre-processing your data or analyzing your results.
#
#
#
# Let’s get started! Tensors are arrays that are the building blocks of a neural network. In this lecture, we will learn the basics of 1-D tensors
#
# such as Types, Indexing and Slicing, Basic Operations, Universal Functions
#
#
#
#
# Let’s start by understanding what a 1 D tensor is
#
# A 0-d tensor is just a number,
#
# 1-D tensor is an array of numbers.
#
# It could be: A row in a data database, A vector, Time series
#
#
#
#
# A tensor contains elements of a single data type.
#
# The tensor type is the type of tensor.
#
# When we are dealing with real numbers, the tensor type could either be a float tensor or a double tensor.
#
# When we are dealing with unsigned integers that are used in 8 bit images, the tensor type is a byte tensor.
#
# ...

# %%
path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\measures-for-insample-evaluation.txt"

data = open(path, "rb")
content = data.read()
data.close()

print(content)
# Out:
# b"\r\nIn this lecture we will cover 1d tensors, and teach you about some of the common operations that you will use with tensors when building a neural network, pre-processing your data or analyzing your results.\r\n\r\n\r\n\r\nLet\xe2\x80\x99s get started! Tensors are arrays that are the building blocks of a neural network. In this lecture, we will learn the basics of 1-D tensors \r\n\r\nsuch as Types, Indexing and Slicing, Basic Operations, Universal Functions\r\n\r\n\r\n\r\n\r\nLet\xe2\x80\x99s start by understanding what a 1 D tensor is \r\n\r\nA 0-d tensor is just a number, \r\n\r\n1-D tensor is an array of numbers. \r\n\r\nIt could be: A row in a data database, A vector, Time series\r\n\r\n\r\n\r\n\r\nA tensor contains elements of a single data type. \r\n\r\nThe tensor type is the type of tensor. \r\n\r\nWhen we are dealing with real numbers, the tensor type could either be a float tensor or a double tensor. \r\n\r\nWhen we are dealing with unsigned integers that are used in 8 
# ...

# %%
import chardet

path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\measures-for-insample-evaluation.txt"

with open(path, 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']

print(f"Detected encoding: {encoding}")
# Out:
# Detected encoding: utf-8

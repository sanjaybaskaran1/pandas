# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
xl = "D:\\DATASETS\\python\\Sales Analysis Report.xlsx"
sheet = "Sales Orders"

# %%
#loading the data without header
df2 = pd.read_excel( xl, sheet_name =sheet, header=None)

# %%
df2.head()
# Out:
#              0                    1                    2   \
# 0   OrderNumber            OrderDate            Ship Date
# 1   SO - 000225  2017-01-01 00:00:00  2017-01-13 00:00:00
# 2  SO - 0003378  2017-01-01 00:00:00  2017-01-06 00:00:00
# 3  SO - 0003901  2017-01-01 00:00:00  2017-01-05 00:00:00
# 4  SO - 0005126  2017-01-01 00:00:00  2017-01-17 00:00:00
#
#                     3            4              5               6   \
# 0  Customer Name Index      Channel  Currency Code  Warehouse Code
# 1                   28    Wholesale            NZD          AXW291
# 2                    7  Distributor            NZD          AXW291
# 3                   12    Wholesale            NZD          AXW291
# 4                    5    Wholesale            USD          AXW291
#
#              7               8               9           10               11  \
# 0  Region Index  Product  Index  Order Quantity  Unit Price  Total Unit Cost
# ...

# %%
#creating the headers
header = ['OrderNumber', 'OrderDate', 'Ship Date', 'Customer Name Index',
       'Channel', 'Currency Code', 'Warehouse Code', 'Region Index',
       'Product  Index', 'Order Quantity', 'Unit Price', 'Total Unit Cost',
       'Total Revenue']

# %%
#renaming the particular column name
df2.columns = header
df2.head()
# Out:
#     OrderNumber            OrderDate            Ship Date  \
# 0   OrderNumber            OrderDate            Ship Date
# 1   SO - 000225  2017-01-01 00:00:00  2017-01-13 00:00:00
# 2  SO - 0003378  2017-01-01 00:00:00  2017-01-06 00:00:00
# 3  SO - 0003901  2017-01-01 00:00:00  2017-01-05 00:00:00
# 4  SO - 0005126  2017-01-01 00:00:00  2017-01-17 00:00:00
#
#    Customer Name Index      Channel  Currency Code  Warehouse Code  \
# 0  Customer Name Index      Channel  Currency Code  Warehouse Code
# 1                   28    Wholesale            NZD          AXW291
# 2                    7  Distributor            NZD          AXW291
# 3                   12    Wholesale            NZD          AXW291
# 4                    5    Wholesale            USD          AXW291
#
#    Region Index  Product  Index  Order Quantity  Unit Price  Total Unit Cost  \
# 0  Region Index  Product  Index  Order Quantity  Unit Price  Total Unit Cost
# ...

# %%
df2 = df2.rename(columns={"OrderNumber" : "ordernumber"})
df2.tail(n=5)
# Out:
#        ordernumber            OrderDate            Ship Date  \
# 7987  SO - 0005237  2019-12-12 00:00:00  2019-12-16 00:00:00
# 7988  SO - 0005477  2019-12-12 00:00:00  2019-12-27 00:00:00
# 7989  SO - 0006936  2019-12-12 00:00:00  2019-12-27 00:00:00
# 7990  SO - 0007126  2019-12-12 00:00:00  2019-12-25 00:00:00
# 7991  SO - 0007668  2019-12-12 00:00:00  2019-12-25 00:00:00
#
#      Customer Name Index      Channel Currency Code Warehouse Code  \
# 7987                  41    Wholesale           NZD         FLR025
# 7988                  28  Distributor           AUD         FLR025
# 7989                  30    Wholesale           NZD         FLR025
# 7990                   6  Distributor           USD         FLR025
# 7991                   4    Wholesale           NZD         FLR025
#
#      Region Index Product  Index Order Quantity Unit Price Total Unit Cost  \
# 7987           93              9              7      261.3         107.133
# ...

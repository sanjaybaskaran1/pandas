# %%
import pandas as pd

# %%
orders = pd.read_excel("C:\\Users\\Sanjay\\OneDrive\\Desktop\\Sales.xlsx")
products = pd.read_excel("C:\\Users\\Sanjay\\OneDrive\\Desktop\\products.xlsx")
regions = pd.read_excel("C:\\Users\\Sanjay\\OneDrive\\Desktop\\regions.xlsx")
customers = pd.read_excel("C:\\Users\\Sanjay\\OneDrive\\Desktop\\customers.xlsx")

# %%
orders.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Total Unit Cost  Total Revenue
# ...

# %%
products.head()
# Out:
#    Index Product Name
# 0      1    Product 1
# 1      2    Product 2
# 2      3    Product 3
# 3      4    Product 4
# 4      5    Product 5

# %%
regions.head()
# Out:
#    Index        Suburb          City  postcode   Longitude   Latitude  \
# 0      1  Freemans Bay      Auckland      1011  174.748652 -36.855732
# 1      2     Nightcaps     Southland      9630  168.028823 -45.970300
# 2      3     Northcote   North Shore       627  174.755505 -36.804712
# 3      4      Bay View        Napier      4104  176.871662 -39.440389
# 4      5     Parklands  Christchurch      8083  172.705997 -43.472699
#
#                               Full Address
# 0    Picton Street, Freemans Bay, Auckland
# 1        Lyne Street, Nightcaps, Southland
# 2   McBreen Avenue, Northcote, North Shore
# 3  Ferguson Street South, Bay View, Napier
# 4    Forest Drive, Parklands, Christchurch

# %%
customers.head()
# Out:
#    Customer Index Customer Names
# 0               1      Avon Corp
# 1               2      WakeFern
# 2               3   Elorac, Corp
# 3               4      ETUDE Ltd
# 4               5   Procter Corp

# %%
products.rename(columns={'Index':'Product Index'}, inplace=True)
products.head()
# Out:
#    Product Index Product Name
# 0              1    Product 1
# 1              2    Product 2
# 2              3    Product 3
# 3              4    Product 4
# 4              5    Product 5

# %%
pd.merge(orders,products,on="Product Index",how="inner", axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.merge(orders,products,on="Product Index",how="inner", axis=1)
#
# TypeError: merge() got an unexpected keyword argument 'axis'

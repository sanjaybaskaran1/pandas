# %%
import pandas as pd
import numpy as np

# %%
path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\pandas\\employees.csv"

# %%
employees_df = pd.read_csv(path)

# %%
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
employees_df.dtypes
# Out:
# emp_no         int64
# birth_date    object
# first_name    object
# last_name     object
# gender        object
# hire_date     object
# dtype: object

# %%
new_df = pd.read_csv(path,parse_dates=(["birth_date","hire_date"]))

# %%
new_df.head()
# Out:
#    emp_no birth_date first_name last_name gender  hire_date
# 0   10001 1953-09-02     Georgi   Facello      M 1986-06-26
# 1   10002 1964-06-02    Bezalel    Simmel      F 1985-11-21
# 2   10003 1959-12-03      Parto   Bamford      M 1986-08-28
# 3   10004 1954-05-01  Chirstian   Koblick      M 1986-12-01
# 4   10005 1955-01-21    Kyoichi  Maliniak      M 1989-09-12

# %%
new_df.dtypes
# Out:
# emp_no                 int64
# birth_date    datetime64[ns]
# first_name            object
# last_name             object
# gender                object
# hire_date     datetime64[ns]
# dtype: object

# %%
new_df["first_name"] == "Georgi"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: first_name, Length: 100, dtype: bool

# %%
new_df[new_df["first_name"] == "Georgi"]
# Out:
#    emp_no birth_date first_name last_name gender  hire_date
# 0   10001 1953-09-02     Georgi   Facello      M 1986-06-26

# %%
new_df[new_df["emp_no"] == 10016]
# Out:
#     emp_no birth_date first_name    last_name gender  hire_date
# 15   10016 1961-05-02   Kazuhito  Cappelletti      M 1995-01-27

# %%
new_df[new_df['emp_no'] > 10080]
# Out:
#     emp_no birth_date   first_name     last_name gender  hire_date
# 80   10081 1960-12-17     Zhongwei         Rosen      M 1986-10-30
# 81   10082 1963-09-09       Parviz         Lortz      M 1990-01-03
# 82   10083 1959-07-23        Vishv       Zockler      M 1987-03-31
# 83   10084 1960-05-25        Tuval      Kalloufi      M 1995-12-15
# 84   10085 1962-11-07      Kenroku     Malabarba      M 1994-04-09
# 85   10086 1962-11-19      Somnath         Foote      M 1990-02-16
# 86   10087 1959-07-23      Xinglin       Eugenio      F 1986-09-08
# 87   10088 1954-02-25     Jungsoon      Syrzycki      F 1988-09-02
# 88   10089 1963-03-21    Sudharsan  Flasterstein      F 1986-08-12
# 89   10090 1961-05-30       Kendra       Hofting      M 1986-03-14
# 90   10091 1955-10-04      Amabile       Gomatam      M 1992-11-18
# 91   10092 1964-10-18    Valdiodio       Niizuma      F 1989-09-22
# 92   10093 1964-06-11      Sailaja       Desikan      M 1996-11-05
# ...

# %%
new_df[new_df['emp_no'] < 10015]
# Out:
#     emp_no birth_date first_name  last_name gender  hire_date
# 0    10001 1953-09-02     Georgi    Facello      M 1986-06-26
# 1    10002 1964-06-02    Bezalel     Simmel      F 1985-11-21
# 2    10003 1959-12-03      Parto    Bamford      M 1986-08-28
# 3    10004 1954-05-01  Chirstian    Koblick      M 1986-12-01
# 4    10005 1955-01-21    Kyoichi   Maliniak      M 1989-09-12
# 5    10006 1953-04-20     Anneke    Preusig      F 1989-06-02
# 6    10007 1957-05-23    Tzvetan  Zielinski      F 1989-02-10
# 7    10008 1958-02-19     Saniya   Kalloufi      M 1994-09-15
# 8    10009 1952-04-19     Sumant       Peac      F 1985-02-18
# 9    10010 1963-06-01  Duangkaew   Piveteau      F 1989-08-24
# 10   10011 1953-11-07       Mary      Sluis      F 1990-01-22
# 11   10012 1960-10-04   Patricio  Bridgland      M 1992-12-18
# 12   10013 1963-06-07  Eberhardt     Terkki      M 1985-10-20
# 13   10014 1956-02-12      Berni      Genin      M 1987-03-11

# %%
pd.set_option('display.max_rows',None)

# %%
new_df
# Out:
#     emp_no birth_date   first_name     last_name gender  hire_date
# 0    10001 1953-09-02       Georgi       Facello      M 1986-06-26
# 1    10002 1964-06-02      Bezalel        Simmel      F 1985-11-21
# 2    10003 1959-12-03        Parto       Bamford      M 1986-08-28
# 3    10004 1954-05-01    Chirstian       Koblick      M 1986-12-01
# 4    10005 1955-01-21      Kyoichi      Maliniak      M 1989-09-12
# 5    10006 1953-04-20       Anneke       Preusig      F 1989-06-02
# 6    10007 1957-05-23      Tzvetan     Zielinski      F 1989-02-10
# 7    10008 1958-02-19       Saniya      Kalloufi      M 1994-09-15
# 8    10009 1952-04-19       Sumant          Peac      F 1985-02-18
# 9    10010 1963-06-01    Duangkaew      Piveteau      F 1989-08-24
# 10   10011 1953-11-07         Mary         Sluis      F 1990-01-22
# 11   10012 1960-10-04     Patricio     Bridgland      M 1992-12-18
# 12   10013 1963-06-07    Eberhardt        Terkki      M 1985-10-20
# ...

# %%
new_df[(new_df['first_name'] == 'Pradeep') & (new_df['gender'] == 'M')]
# Out:
#     emp_no birth_date first_name last_name gender  hire_date
# 36   10037 1963-07-22    Pradeep  Makrucki      M 1990-12-05

# %%
new_df[(new_df['first_name'] == 'Pradeep') | (new_df['first_name'] != 'Arumugam')]
# Out:
#     emp_no birth_date   first_name     last_name gender  hire_date
# 0    10001 1953-09-02       Georgi       Facello      M 1986-06-26
# 1    10002 1964-06-02      Bezalel        Simmel      F 1985-11-21
# 2    10003 1959-12-03        Parto       Bamford      M 1986-08-28
# 3    10004 1954-05-01    Chirstian       Koblick      M 1986-12-01
# 4    10005 1955-01-21      Kyoichi      Maliniak      M 1989-09-12
# 5    10006 1953-04-20       Anneke       Preusig      F 1989-06-02
# 6    10007 1957-05-23      Tzvetan     Zielinski      F 1989-02-10
# 7    10008 1958-02-19       Saniya      Kalloufi      M 1994-09-15
# 8    10009 1952-04-19       Sumant          Peac      F 1985-02-18
# 9    10010 1963-06-01    Duangkaew      Piveteau      F 1989-08-24
# 10   10011 1953-11-07         Mary         Sluis      F 1990-01-22
# 11   10012 1960-10-04     Patricio     Bridgland      M 1992-12-18
# 12   10013 1963-06-07    Eberhardt        Terkki      M 1985-10-20
# ...

# %%
filter1 = new_df['emp_no'] > 10060

# %%
new_df.loc[filter1,"emp_no":"gender"]
# Out:
#     emp_no birth_date   first_name     last_name gender
# 60   10061 1962-10-19          Tse        Herber      M
# 61   10062 1961-11-02       Anoosh          Peyn      M
# 62   10063 1952-08-06         Gino     Leonhardt      F
# 63   10064 1959-04-07          Udi        Jansch      M
# 64   10065 1963-04-14       Satosi         Awdeh      M
# 65   10066 1952-11-13         Kwee      Schusler      M
# 66   10067 1953-01-07       Claudi      Stavenow      M
# 67   10068 1962-11-26     Charlene       Brattka      M
# 68   10069 1960-09-06    Margareta       Bierman      F
# 69   10070 1955-08-20       Reuven    Garigliano      M
# 70   10071 1958-01-21        Hisao        Lipner      M
# 71   10072 1952-05-15     Hironoby         Sidou      F
# 72   10073 1954-02-23         Shir       McClurg      M
# 73   10074 1955-08-28      Mokhtar     Bernatsky      F
# 74   10075 1960-03-09          Gao      Dolinsky      F
# 75   10076 1952-06-13         Erez      Ritzmann      F
# ...

# %%
names_list = ["Pradeep","Sreekrishna","Arumugam","Sailaja"]

# %%
filter2 = new_df["first_name"].isin(names_list)

# %%
new_df.loc[filter2,["first_name","last_name","gender"]]
# Out:
#      first_name     last_name gender
# 36      Pradeep      Makrucki      M
# 92      Sailaja       Desikan      M
# 93     Arumugam  Ossenbruggen      F
# 97  Sreekrishna     Servieres      F

# %%
new_df[new_df["first_name"].str.contains("S")]
# Out:
#     emp_no birth_date   first_name     last_name gender  hire_date
# 7    10008 1958-02-19       Saniya      Kalloufi      M 1994-09-15
# 8    10009 1952-04-19       Sumant          Peac      F 1985-02-18
# 21   10022 1952-07-08       Shahaf        Famili      M 1995-08-22
# 23   10024 1958-09-05      Suzette        Pettey      F 1997-05-19
# 52   10053 1954-09-13       Sanjiv      Zschoche      F 1986-02-04
# 64   10065 1963-04-14       Satosi         Awdeh      M 1988-05-18
# 72   10073 1954-02-23         Shir       McClurg      M 1991-12-01
# 85   10086 1962-11-19      Somnath         Foote      M 1990-02-16
# 88   10089 1963-03-21    Sudharsan  Flasterstein      F 1986-08-12
# 92   10093 1964-06-11      Sailaja       Desikan      M 1996-11-05
# 97   10098 1961-09-23  Sreekrishna     Servieres      F 1985-05-13

# %%
import pandas as pd
data = {
    "name" : ["lavanya","jaanu","lakshith","lavanya","lavanya","dakshith","jaanu","keerthu","sanjana"],
    "age" : [20, 21, 10, 20, 20, 7, 21,10,8]
}
df2 = pd.DataFrame(data)
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
filt = df2.duplicated(keep='first')
df2.loc[filt]
# Out:
#       name  age
# 3  lavanya   20
# 4  lavanya   20
# 6    jaanu   21

# %%
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
filt2 = df2.duplicated(keep='last')
df2.loc[filt2]
# Out:
#       name  age
# 0  lavanya   20
# 1    jaanu   21
# 3  lavanya   20

# %%
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
filt3 = df2.duplicated(keep=False)
df2.loc[filt3]
# Out:
#       name  age
# 0  lavanya   20
# 1    jaanu   21
# 3  lavanya   20
# 4  lavanya   20
# 6    jaanu   21

# %%
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
df2.drop_duplicates(keep='first')
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 5  dakshith    7
# 7   keerthu   10
# 8   sanjana    8

# %%
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
df2.drop_duplicates(keep='last')
# Out:
#        name  age
# 2  lakshith   10
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
df2
# Out:
#        name  age
# 0   lavanya   20
# 1     jaanu   21
# 2  lakshith   10
# 3   lavanya   20
# 4   lavanya   20
# 5  dakshith    7
# 6     jaanu   21
# 7   keerthu   10
# 8   sanjana    8

# %%
df2.drop_duplicates(keep=False, inplace=True)

# %%
df2
# Out:
#        name  age
# 2  lakshith   10
# 5  dakshith    7
# 7   keerthu   10
# 8   sanjana    8

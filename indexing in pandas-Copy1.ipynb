# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Sanjay\\OneDrive\\Desktop\\pandas\\employees2.csv")
print(df.head(n=2))
print(type(df))
# Out:
#    emp_no first_name last_name   hire_date  salary
# 0   10001     Georgi   Facello  1986-06-26   60117
# 1   10001     Georgi   Facello  1986-06-26   62102
# <class 'pandas.core.frame.DataFrame'>

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#      emp_no first_name    last_name   hire_date  salary
# 0     10001     Georgi      Facello  1986-06-26   60117
# 1     10001     Georgi      Facello  1986-06-26   62102
# 2     10001     Georgi      Facello  1986-06-26   66074
# 3     10001     Georgi      Facello  1986-06-26   66596
# 4     10001     Georgi      Facello  1986-06-26   66961
# 5     10001     Georgi      Facello  1986-06-26   71046
# 6     10001     Georgi      Facello  1986-06-26   74333
# 7     10001     Georgi      Facello  1986-06-26   75286
# 8     10001     Georgi      Facello  1986-06-26   75994
# 9     10001     Georgi      Facello  1986-06-26   76884
# 10    10001     Georgi      Facello  1986-06-26   80013
# 11    10001     Georgi      Facello  1986-06-26   81025
# 12    10001     Georgi      Facello  1986-06-26   81097
# 13    10001     Georgi      Facello  1986-06-26   84917
# 14    10001     Georgi      Facello  1986-06-26   85112
# 15    10001     Georgi      Facello  1986-06-26   85097
# ...

# %%
df.tail(n=4)
# Out:
#      emp_no first_name last_name   hire_date  salary
# 296   10032      Jeong   Reistad  1990-06-20   57926
# 297   10032      Jeong   Reistad  1990-06-20   57876
# 298   10032      Jeong   Reistad  1990-06-20   61709
# 299   10032      Jeong   Reistad  1990-06-20   65820

# %%
print(df.iloc[299])
print(type(df.iloc[299]))
# Out:
# emp_no             10032
# first_name         Jeong
# last_name        Reistad
# hire_date     1990-06-20
# salary             65820
# Name: 299, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(type(df['emp_no']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head(n=51)
# Out:
#     emp_no first_name last_name   hire_date  salary
# 0    10001     Georgi   Facello  1986-06-26   60117
# 1    10001     Georgi   Facello  1986-06-26   62102
# 2    10001     Georgi   Facello  1986-06-26   66074
# 3    10001     Georgi   Facello  1986-06-26   66596
# 4    10001     Georgi   Facello  1986-06-26   66961
# 5    10001     Georgi   Facello  1986-06-26   71046
# 6    10001     Georgi   Facello  1986-06-26   74333
# 7    10001     Georgi   Facello  1986-06-26   75286
# 8    10001     Georgi   Facello  1986-06-26   75994
# 9    10001     Georgi   Facello  1986-06-26   76884
# 10   10001     Georgi   Facello  1986-06-26   80013
# 11   10001     Georgi   Facello  1986-06-26   81025
# 12   10001     Georgi   Facello  1986-06-26   81097
# 13   10001     Georgi   Facello  1986-06-26   84917
# 14   10001     Georgi   Facello  1986-06-26   85112
# 15   10001     Georgi   Facello  1986-06-26   85097
# 16   10001     Georgi   Facello  1986-06-26   88958
# ...

# %%
print(df.iloc[[50,250]])
print(type(df.iloc[[50,250]]))
# Out:
#      emp_no first_name last_name   hire_date  salary
# 50    10005    Kyoichi  Maliniak  1989-09-12   85572
# 250   10028   Domenick  Tempesti  1991-10-22   48859
# <class 'pandas.core.frame.DataFrame'>

# %%
x = df.iloc[[50,250]]
x['emp_no']
type(x['emp_no'])
# Out:
# pandas.core.series.Series

# %%
df.head(n=104)
# Out:
#      emp_no first_name  last_name   hire_date  salary
# 0     10001     Georgi    Facello  1986-06-26   60117
# 1     10001     Georgi    Facello  1986-06-26   62102
# 2     10001     Georgi    Facello  1986-06-26   66074
# 3     10001     Georgi    Facello  1986-06-26   66596
# 4     10001     Georgi    Facello  1986-06-26   66961
# 5     10001     Georgi    Facello  1986-06-26   71046
# 6     10001     Georgi    Facello  1986-06-26   74333
# 7     10001     Georgi    Facello  1986-06-26   75286
# 8     10001     Georgi    Facello  1986-06-26   75994
# 9     10001     Georgi    Facello  1986-06-26   76884
# 10    10001     Georgi    Facello  1986-06-26   80013
# 11    10001     Georgi    Facello  1986-06-26   81025
# 12    10001     Georgi    Facello  1986-06-26   81097
# 13    10001     Georgi    Facello  1986-06-26   84917
# 14    10001     Georgi    Facello  1986-06-26   85112
# 15    10001     Georgi    Facello  1986-06-26   85097
# ...

# %%
df.iloc[100:103,0:5]
# Out:
#      emp_no first_name last_name   hire_date  salary
# 100   10009     Sumant      Peac  1985-02-18   82507
# 101   10009     Sumant      Peac  1985-02-18   85875
# 102   10009     Sumant      Peac  1985-02-18   89324

# %%
df.head(n=10)
# Out:
#    emp_no first_name last_name   hire_date  salary
# 0   10001     Georgi   Facello  1986-06-26   60117
# 1   10001     Georgi   Facello  1986-06-26   62102
# 2   10001     Georgi   Facello  1986-06-26   66074
# 3   10001     Georgi   Facello  1986-06-26   66596
# 4   10001     Georgi   Facello  1986-06-26   66961
# 5   10001     Georgi   Facello  1986-06-26   71046
# 6   10001     Georgi   Facello  1986-06-26   74333
# 7   10001     Georgi   Facello  1986-06-26   75286
# 8   10001     Georgi   Facello  1986-06-26   75994
# 9   10001     Georgi   Facello  1986-06-26   76884

# %%
df.iloc[[0,4,6,9],[1,3]]
# Out:
#   first_name   hire_date
# 0     Georgi  1986-06-26
# 4     Georgi  1986-06-26
# 6     Georgi  1986-06-26
# 9     Georgi  1986-06-26

# %%
df.head()
# Out:
#    emp_no first_name last_name   hire_date  salary
# 0   10001     Georgi   Facello  1986-06-26   60117
# 1   10001     Georgi   Facello  1986-06-26   62102
# 2   10001     Georgi   Facello  1986-06-26   66074
# 3   10001     Georgi   Facello  1986-06-26   66596
# 4   10001     Georgi   Facello  1986-06-26   66961

# %%
df.loc[0,"last_name"]
# Out:
# 'Facello'

# %%
df
# Out:
#      emp_no first_name    last_name   hire_date  salary
# 0     10001     Georgi      Facello  1986-06-26   60117
# 1     10001     Georgi      Facello  1986-06-26   62102
# 2     10001     Georgi      Facello  1986-06-26   66074
# 3     10001     Georgi      Facello  1986-06-26   66596
# 4     10001     Georgi      Facello  1986-06-26   66961
# 5     10001     Georgi      Facello  1986-06-26   71046
# 6     10001     Georgi      Facello  1986-06-26   74333
# 7     10001     Georgi      Facello  1986-06-26   75286
# 8     10001     Georgi      Facello  1986-06-26   75994
# 9     10001     Georgi      Facello  1986-06-26   76884
# 10    10001     Georgi      Facello  1986-06-26   80013
# 11    10001     Georgi      Facello  1986-06-26   81025
# 12    10001     Georgi      Facello  1986-06-26   81097
# 13    10001     Georgi      Facello  1986-06-26   84917
# 14    10001     Georgi      Facello  1986-06-26   85112
# 15    10001     Georgi      Facello  1986-06-26   85097
# ...

# %%
x_df = df.loc[[0,4,7,10,50],["first_name","hire_date","emp_no"]]
x_df
# Out:
#    first_name   hire_date  emp_no
# 0      Georgi  1986-06-26   10001
# 4      Georgi  1986-06-26   10001
# 7      Georgi  1986-06-26   10001
# 10     Georgi  1986-06-26   10001
# 50    Kyoichi  1989-09-12   10005

# %%
df.loc[50:60,"emp_no":"hire_date"]
# Out:
#     emp_no first_name last_name   hire_date
# 50   10005    Kyoichi  Maliniak  1989-09-12
# 51   10005    Kyoichi  Maliniak  1989-09-12
# 52   10005    Kyoichi  Maliniak  1989-09-12
# 53   10005    Kyoichi  Maliniak  1989-09-12
# 54   10005    Kyoichi  Maliniak  1989-09-12
# 55   10005    Kyoichi  Maliniak  1989-09-12
# 56   10005    Kyoichi  Maliniak  1989-09-12
# 57   10005    Kyoichi  Maliniak  1989-09-12
# 58   10005    Kyoichi  Maliniak  1989-09-12
# 59   10005    Kyoichi  Maliniak  1989-09-12
# 60   10006     Anneke   Preusig  1989-06-02

# %%
df.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
data_dict = {
    "name":["lavanya","jaanu","lakshith","dakshith"],
    "marks":[99,98,89,87]
}
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 data_dict = {
#       2     "name":["lavanya","jaanu","lakshith","dakshith"],
#       3     "marks":[99,98,89,87]
#       4 }
# ----> 5 data
#
# NameError: name 'data' is not defined

# %%
df2 = pd.DataFrame(data = data_dict )
df2

# %%
df2.index = ["i","ii","iii","iv"]

# %%
df2

# %%
df2.set_index("name",inplace=True)

# %%
df2

# %%
df2.loc[["lavanya","jaanu"]]

# %%
df2

# %%
df2.index

# %%
df2

# %%
df2.loc[["lavanya","jaanu"]]

# %%
df2.index

# %%
df

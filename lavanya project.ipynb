# %%
#employees data analysis project

import pandas as pd

# %%
#load the data
#and see the first 10 rows
df = pd.read_csv("C:\\Users\\Sanjay\\OneDrive\\Desktop\\pandas\\employees project.csv")
df.head(n=10)
# Out:
#    emp_no dept_no         dept_name first_name last_name gender   hire_date  \
# 0   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 1   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 2   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 3   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 4   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 5   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 6   10011    d009  Customer Service       Mary     Sluis      F  1990-01-22
# 7   10038    d009  Customer Service       Huan     Lortz      M  1989-09-20
# 8   10038    d009  Customer Service       Huan     Lortz      M  1989-09-20
# 9   10038    d009  Customer Service       Huan     Lortz      M  1989-09-20
#
#     salary         title
# 0  42365.0         Staff
# 1  44200.0         Staff
# 2  48214.0         Staff
# 3  50927.0         Staff
# ...

# %%
#see last 10 rows in the dataset
df.tail(n=10)
# Out:
#         emp_no dept_no    dept_name first_name  last_name gender   hire_date  \
# 207482   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207483   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207484   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207485   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207486   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207487   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207488   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207489   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207490   28645    d005  Development   Djelloul    Decleir      F  1991-12-25
# 207491   28645    d005  Development      Djell        NaN    NaN         NaN
#
#           salary            title
# 207482   80698.0         Engineer
# 207483   83585.0         Engineer
# ...

# %%
#see how many rows and columns in dataset
df.shape
# Out:
# (207492, 9)

# %%
#see all the columns in the dataset
df.columns
# Out:
# Index(['emp_no', 'dept_no', 'dept_name', 'first_name', 'last_name', 'gender',
#        'hire_date', 'salary', 'title'],
#       dtype='object')

# %%
#see all the index in the dataset
df.index
# Out:
# RangeIndex(start=0, stop=207492, step=1)

# %%
#use info() to get information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207492 entries, 0 to 207491
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      207492 non-null  int64
#  1   dept_no     207492 non-null  object
#  2   dept_name   207492 non-null  object
#  3   first_name  207492 non-null  object
#  4   last_name   207491 non-null  object
#  5   gender      207491 non-null  object
#  6   hire_date   207491 non-null  object
#  7   salary      207491 non-null  float64
#  8   title       207491 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 14.2+ MB

# %%
#see the statistical of the details of the numerical data-typed column
df.describe()
# Out:
#               emp_no         salary
# count  207492.000000  207491.000000
# mean    45692.451410   59606.414611
# std     34192.239906   14837.457653
# min     10001.000000   38836.000000
# 25%     19310.000000   48117.000000
# 50%     28433.000000   57030.000000
# 75%     70098.000000   68031.500000
# max    201756.000000  144866.000000

# %%
#see the statistical of the details of the all data-typed column
df.describe(include="all")
# Out:
#                emp_no dept_no         dept_name first_name last_name  gender  \
# count   207492.000000  207492            207492     207492    207491  207491
# unique            NaN       2                 2       1276      1636       2
# top               NaN    d009  Customer Service     Pranav   Haddadi       M
# freq              NaN  125189            125189        454       364  125279
# mean     45692.451410     NaN               NaN        NaN       NaN     NaN
# std      34192.239906     NaN               NaN        NaN       NaN     NaN
# min      10001.000000     NaN               NaN        NaN       NaN     NaN
# 25%      19310.000000     NaN               NaN        NaN       NaN     NaN
# 50%      28433.000000     NaN               NaN        NaN       NaN     NaN
# 75%      70098.000000     NaN               NaN        NaN       NaN     NaN
# max     201756.000000     NaN               NaN        NaN       NaN     NaN
#
# ...

# %%
#find how many null values in the dataset for each columns
df.isnull().sum()
# Out:
# emp_no        0
# dept_no       0
# dept_name     0
# first_name    0
# last_name     1
# gender        1
# hire_date     1
# salary        1
# title         1
# dtype: int64

# %%
#find the unique department_names in the data
df['dept_name'].unique()
# Out:
# array(['Customer Service', 'Development'], dtype=object)

# %%
#grab the data of all employees belong to dept_name customer service
filt = df['dept_name'] == 'Customer Service'
df.loc[filt]
# Out:
#         emp_no dept_no         dept_name first_name last_name gender  \
# 0        10011    d009  Customer Service       Mary     Sluis      F
# 1        10011    d009  Customer Service       Mary     Sluis      F
# 2        10011    d009  Customer Service       Mary     Sluis      F
# 3        10011    d009  Customer Service       Mary     Sluis      F
# 4        10011    d009  Customer Service       Mary     Sluis      F
# ...        ...     ...               ...        ...       ...    ...
# 125184  201756    d009  Customer Service       Mart     Oxman      F
# 125185  201756    d009  Customer Service       Mart     Oxman      F
# 125186  201756    d009  Customer Service       Mart     Oxman      F
# 125187  201756    d009  Customer Service       Mart     Oxman      F
# 125188  201756    d009  Customer Service       Mart     Oxman      F
#
#          hire_date   salary  title
# 0       1990-01-22  42365.0  Staff
# 1       1990-01-22  44200.0  Staff
# ...

# %%
# grab the data of all employees belong to dept_name Customer service and gender female
filt2 = (df['dept_name'] == 'Customer Service') & (df['gender'] == 'F')
df.loc[filt2]
# Out:
#         emp_no dept_no         dept_name first_name last_name gender  \
# 0        10011    d009  Customer Service       Mary     Sluis      F
# 1        10011    d009  Customer Service       Mary     Sluis      F
# 2        10011    d009  Customer Service       Mary     Sluis      F
# 3        10011    d009  Customer Service       Mary     Sluis      F
# 4        10011    d009  Customer Service       Mary     Sluis      F
# ...        ...     ...               ...        ...       ...    ...
# 125184  201756    d009  Customer Service       Mart     Oxman      F
# 125185  201756    d009  Customer Service       Mart     Oxman      F
# 125186  201756    d009  Customer Service       Mart     Oxman      F
# 125187  201756    d009  Customer Service       Mart     Oxman      F
# 125188  201756    d009  Customer Service       Mart     Oxman      F
#
#          hire_date   salary  title
# 0       1990-01-22  42365.0  Staff
# 1       1990-01-22  44200.0  Staff
# ...

# %%
# grab the data of all employees belong to dept_name Customer service and gender male
filt3 = (df['dept_name'] == 'Customer Service') & (df['gender'] == 'M')
df.loc[filt3]
# Out:
#         emp_no dept_no         dept_name first_name last_name gender  \
# 7        10038    d009  Customer Service       Huan     Lortz      M
# 8        10038    d009  Customer Service       Huan     Lortz      M
# 9        10038    d009  Customer Service       Huan     Lortz      M
# 10       10038    d009  Customer Service       Huan     Lortz      M
# 11       10038    d009  Customer Service       Huan     Lortz      M
# ...        ...     ...               ...        ...       ...    ...
# 125133  201691    d009  Customer Service     Kellyn   Soloway      M
# 125134  201702    d009  Customer Service   Teruyuki   Doering      M
# 125135  201702    d009  Customer Service   Teruyuki   Doering      M
# 125136  201702    d009  Customer Service   Teruyuki   Doering      M
# 125137  201702    d009  Customer Service   Teruyuki   Doering      M
#
#          hire_date   salary         title
# 7       1989-09-20  40000.0  Senior Staff
# 8       1989-09-20  43527.0  Senior Staff
# ...

# %%
#grab the data of all employees belong to dept_name Development
filt4 = df['dept_name'] == 'Development'
df.loc[filt4]
# Out:
#         emp_no dept_no    dept_name first_name  last_name gender   hire_date  \
# 125189   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125190   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125191   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125192   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125193   10001    d005  Development     Georgi    Facello      M  1986-06-26
# ...        ...     ...          ...        ...        ...    ...         ...
# 207487   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207488   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207489   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207490   28645    d005  Development   Djelloul    Decleir      F  1991-12-25
# 207491   28645    d005  Development      Djell        NaN    NaN         NaN
#
#           salary            title
# ...

# %%
# grab the data of all employees belong to dept_name Customer service and gender female
filt5 = (df['dept_name'] == 'Development') & (df['gender'] == 'F')
df.loc[filt5]
# Out:
#         emp_no dept_no    dept_name first_name last_name gender   hire_date  \
# 125206   10006    d005  Development     Anneke   Preusig      F  1989-06-02
# 125207   10006    d005  Development     Anneke   Preusig      F  1989-06-02
# 125208   10006    d005  Development     Anneke   Preusig      F  1989-06-02
# 125209   10006    d005  Development     Anneke   Preusig      F  1989-06-02
# 125210   10006    d005  Development     Anneke   Preusig      F  1989-06-02
# ...        ...     ...          ...        ...       ...    ...         ...
# 207477   28631    d005  Development     Dmitry  Marletta      F  1988-12-30
# 207478   28631    d005  Development     Dmitry  Marletta      F  1988-12-30
# 207479   28631    d005  Development     Dmitry  Marletta      F  1988-12-30
# 207480   28631    d005  Development     Dmitry  Marletta      F  1988-12-30
# 207490   28645    d005  Development   Djelloul   Decleir      F  1991-12-25
#
#           salary            title
# ...

# %%
# grab the data of all employees belong to dept_name Customer service and gender male
filt5 = (df['dept_name'] == 'Development') & (df['gender'] == 'M')
df.loc[filt5]
# Out:
#         emp_no dept_no    dept_name first_name  last_name gender   hire_date  \
# 125189   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125190   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125191   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125192   10001    d005  Development     Georgi    Facello      M  1986-06-26
# 125193   10001    d005  Development     Georgi    Facello      M  1986-06-26
# ...        ...     ...          ...        ...        ...    ...         ...
# 207485   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207486   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207487   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207488   28644    d005  Development      Marla  Heiserman      M  1987-05-31
# 207489   28644    d005  Development      Marla  Heiserman      M  1987-05-31
#
#           salary            title
# ...

# %%
#remove the null values from the dataset
df.dropna(inplace=True)

# %%
#check whether all null values are removed
df.isnull().sum()
# Out:
# emp_no        0
# dept_no       0
# dept_name     0
# first_name    0
# last_name     0
# gender        0
# hire_date     0
# salary        0
# title         0
# dtype: int64

# %%
import pandas as pd

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB 326.8 kB/s eta 0:00:44
#    ---------------------------------------- 0.1/14.3 MB 435.7 kB/s eta 0:00:33
#    ---------------------------------------- 0.2/14.3 MB 762.6 kB/s eta 0:00:19
#     --------------------------------------- 0.2/14.3 MB 871.5 kB/s eta 0:00:17
#     --------------------------------------- 0.3/14.3 MB 1.0 MB/s eta 0:00:14
#    - -------------------------------------- 0.4/14.3 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/14.3 MB 1.2 MB/s eta 0:00:12
#    - -------------------------------------- 0.6/14.3 MB 1.3 MB/s eta 0:00:11
#    - -------------------------------------- 0.7/14.3 MB 1.4 MB/s eta 0:00:10
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'bondings'

# CSV file path
csv_file_path = 'C:\\Users\\Sanjay\\OneDrive\\Desktop\\DATASETS\\ipl-2024.csv'

# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Write the DataFrame to a MySQL table
df.to_sql('ipl_data', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'bondings'

# CSV file path
csv_file_path = 'C:\\Users\\Sanjay\\OneDrive\\Desktop\\DATASETS\\ipl-2024.csv'

# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Write the DataFrame to a MySQL table
df.to_sql('ipl_data2', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'bondings'

# CSV file path
csv_file_path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\DATASETS\\insurance.csv"

# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Write the DataFrame to a MySQL table
df.to_sql('insurance_data', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
csv_file_path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\bondings\\project\\orders.csv"
df = pd.read_csv(csv_file_path)
df.dtypes
# Out:
# OrderNumber            object
# OrderDate              object
# Ship Date              object
# Customer Name Index     int64
# Channel                object
# Currency Code          object
# Warehouse Code         object
# Region Index            int64
# Product  Index          int64
# Order Quantity          int64
# Unit Price             object
# Total Unit Cost        object
# Total Revenue          object
# dtype: object

# %%
df.head()
# Out:
#     OrderNumber  OrderDate   Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225  1-01-2017  13-01-2017                   28    Wholesale
# 1  SO - 0003378  1-01-2017  06-01-2017                    7  Distributor
# 2  SO - 0003901  1-01-2017  05-01-2017                   12    Wholesale
# 3  SO - 0005126  1-01-2017  17-01-2017                    5    Wholesale
# 4  SO - 0005614  1-01-2017  07-01-2017                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#   Unit Price Total Unit Cost Total Revenue
# ...

# %%
df.rename(columns={"Unit Price":"Selling Price", "Total Unit Cost":"Cost Price"}, inplace=True)
df.head()
# Out:
#     OrderNumber  OrderDate   Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225  1-01-2017  13-01-2017                   28    Wholesale
# 1  SO - 0003378  1-01-2017  06-01-2017                    7  Distributor
# 2  SO - 0003901  1-01-2017  05-01-2017                   12    Wholesale
# 3  SO - 0005126  1-01-2017  17-01-2017                    5    Wholesale
# 4  SO - 0005614  1-01-2017  07-01-2017                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#   Selling Price Cost Price Total Revenue
# ...

# %%
df.astype({"Selling Price":"float", "Cost Price":"float", "Total Revenue":"float"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.astype({"Selling Price":"float", "Cost Price":"float", "Total Revenue":"float"})
#
# File ~\anaconda3\New folder\anaconda\Lib\site-packages\pandas\core\generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# File ~\anaconda3\New folder\anaconda\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
# ...

# %%
df['Selling Price']=df['Selling Price'].str.replace(",","")
df['Selling Price']
# Out:
# 0       2499.10
# 1       2351.70
# 2       1728.60
# 3        978.20
# 4       2338.30
#          ...
# 7986     261.30
# 7987    1996.60
# 7988    3912.80
# 7989    1855.90
# 7990    3959.70
# Name: Selling Price, Length: 7991, dtype: object

# %%
df['Cost Price']=df['Cost Price'].str.replace(",","")
df['Cost Price']
# Out:
# 0       1824.34
# 1       1269.92
# 2       1019.87
# 3        684.74
# 4       1028.85
#          ...
# 7986     107.13
# 7987    1477.48
# 7988    2817.22
# 7989    1113.54
# 7990    2138.24
# Name: Cost Price, Length: 7991, dtype: object

# %%
df['Total Revenue']=df['Total Revenue'].str.replace(",","")
df['Total Revenue']
# Out:
# 0       14994.60
# 1       25868.70
# 2        8643.00
# 3        5869.20
# 4       16368.10
#           ...
# 7986     1829.10
# 7987    13976.20
# 7988    35215.20
# 7989    18559.00
# 7990    43556.70
# Name: Total Revenue, Length: 7991, dtype: object

# %%
df[["Selling Price","Cost Price","Total Revenue"]]=df[["Selling Price","Cost Price","Total Revenue"]].astype({"Selling Price":"float", 
                                                                                                               "Cost Price":"float", 
                                                                                                              "Total Revenue":"float"})

# %%
df.dtypes
# Out:
# OrderNumber             object
# OrderDate               object
# Ship Date               object
# Customer Name Index      int64
# Channel                 object
# Currency Code           object
# Warehouse Code          object
# Region Index             int64
# Product  Index           int64
# Order Quantity           int64
# Selling Price          float64
# Cost Price             float64
# Total Revenue          float64
# dtype: object

# %%
df['OrderDate']
# Out:
# 0        1-01-2017
# 1        1-01-2017
# 2        1-01-2017
# 3        1-01-2017
# 4        1-01-2017
#            ...
# 7986    12-12-2019
# 7987    12-12-2019
# 7988    12-12-2019
# 7989    12-12-2019
# 7990    12-12-2019
# Name: OrderDate, Length: 7991, dtype: object

# %%
df['Ship Date']
# Out:
# 0       13-01-2017
# 1       06-01-2017
# 2       05-01-2017
# 3       17-01-2017
# 4       07-01-2017
#            ...
# 7986    16-12-2019
# 7987    27-12-2019
# 7988    27-12-2019
# 7989    25-12-2019
# 7990    25-12-2019
# Name: Ship Date, Length: 7991, dtype: object

# %%
df[['OrderDate','Ship Date']]=df[['OrderDate','Ship Date']].apply(pd.to_datetime, format="%d-%m-%Y")
df[['OrderDate','Ship Date']].dtypes
# Out:
# OrderDate    datetime64[ns]
# Ship Date    datetime64[ns]
# dtype: object

# %%
df.dtypes
# Out:
# OrderNumber                    object
# OrderDate              datetime64[ns]
# Ship Date              datetime64[ns]
# Customer Name Index             int64
# Channel                        object
# Currency Code                  object
# Warehouse Code                 object
# Region Index                    int64
# Product  Index                  int64
# Order Quantity                  int64
# Selling Price                 float64
# Cost Price                    float64
# Total Revenue                 float64
# dtype: object

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'sales_analysis'



# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

print(df.head())
# Write the DataFrame to a MySQL table
df.to_sql('orders', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Selling Price  Cost Price  Total Revenue
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'sales_analysis'

# CSV file path
csv_file_path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\bondings\\project\\customers.csv"

# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Write the DataFrame to a MySQL table
df.to_sql('customers', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
username = 'root'
password = 'root'
host = '127.0.0.1'  # e.g., 'localhost'
port = '3306'  # Default MySQL port
database = 'sales_analysis'

# CSV file path
csv_file_path = "C:\\Users\\Sanjay\\OneDrive\\Desktop\\bondings\\project\\products.csv"

# Create a SQLAlchemy engine for MySQL
engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Write the DataFrame to a MySQL table
df.to_sql('products', con=engine, if_exists='replace', index=False)

print("Data loaded successfully.")
